# %% [markdown]
# <a href="https://colab.research.google.com/github/Violet-WM/TEACH2GIVE-TEST/blob/main/python_for_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
import torch
x = torch.tensor(2.0,requires_grad=True)
y = x**3 + 2*x**2 +x +5
y.backward()
print(x)
# Out:
# tensor(2., requires_grad=True)

# %%
pip install numpy torch

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
array,tensor=np.array([1,2,3,4]),torch.tensor([1,2,3,4])
print (array,tensor)
# Out:
# [1 2 3 4] tensor([1, 2, 3, 4])

# %%
array,tensor=np.array([[1,2,3],[2,4,6],[6,8,10]]),torch.tensor([[1,2,3],[2,4,6],[6,8,10]])
plt.imshow (array)

# %%
array,tensor = np.zeros((50,40,3)),torch.tensor((50,40,3))
#print (array,tensor)
plt.imshow (array)

# %%
array[:20,:20,:]=1
plt.imshow (array)

# %%
array[::5,::5,:]=1
plt.imshow (array)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
array[::5,::5,:]=1
plt.imshow (array[:,:,0].T)

# %%
img=plt.imread('/content/rabbit.jpeg')
plt.imshow(img)

# %%
img.shape
# Out:
# (194, 260, 3)

# %%
img1=img.copy()

# %%
img1[:30,:30,:]=255
plt.imshow (img1)

# %%
img.max()
# Out:
# 255

# %%
img.min()
# Out:
# 0

# %%
img.dtype
# Out:
# dtype('uint8')
